# %% [markdown]
# # Laboratory 4: Getting started with Pytorch
#
# In this laboratory we will begin working with Pytorch to implement and train complex, nonlinear models for supervised learning problems. You will notice many similarities between Numpy and Pytorch -- this is deliberate, but it can cause some confusion and for many things we will have to convert back and forth between Numpy arrays and Pytorch tensors.

# %% [markdown]
# ## Part 0: First steps
#
# **Important**: You **must** install Pytorch in your Anaconda environment for this laboratory. The easiest way to do this is to just install the CPU version of Pytorch like this:
#
# ```
# conda activate FML
# conda install -c pytorch pytorch torchvision
# ```
#
# **Note**: If you have an Nvidia GPU on your computer you can also install the GPU-enabled version of Pytorch which will **greatly** improve performance for more complex models and larger datasets. However, it can be very hard to get all of the versions of the required libraries to match correctly... During the laboratory we can look at it together if you are interested.
#
# After installing Pytorch, use the next cell to verify that the installation is working. If it prints a 3x3 sensor, we're good to go.

# %%
# We're still going to need numpy and matplotlib.
import numpy as np
import matplotlib.pyplot as plt

# Verify that pytorch is working.
import torch

foo = torch.randn((3, 3))
print(foo)
# Out:
# tensor([[ 1.0707, -0.4754,  0.0877],
#         [ 0.4567, -0.5677,  0.0030],
#         [-0.6592,  0.1467, -1.2325]])

# %%
import warnings
# Ignora tutti gli avvisi
warnings.filterwarnings("ignore") # ci serve per non mostrare in output (almeno per il momento) alcuni warning di poco conto delle celle successive

# %% [markdown]
# ## Part 1: Dataset preparation

# %% [markdown]
# We will work with the venerable MNIST dataset of handwritten digits in this laboratory. The `torchvision` library provides classes for a bunch of standard datasets, including MNIST. These classes automatically download and prepare the dataset for use.

# %%
# Download and load the MNIST dataset.
from torchvision.datasets import MNIST
import torchvision

# Load the MNIST training and test splits.
ds_train = MNIST(root='./data', download=True, train=True)
ds_test  = MNIST(root='./data', download=True, train=False)

# %% [markdown]
# ### Exercise 1.1: Exploratory data analysis
#
# Spend some time inspecting the `ds_train` and `ds_test` data structures in order to get a feel for the data. What is the format? How big are the images? How many are there? What about the range of pixel values? Where are the labels for images?
#
# Remember that one of the best ways to explore is to *visualize*.

# %%
print(f"# of images in training set: {len(ds_train)}")
print(f"# of images in test set: {len(ds_test)}")
# Out:
# # of images in training set: 60000
# # of images in test set: 10000

# %%
image, label = ds_train[0]
print(f"Image dimension: {image.size}")
print(f"Range of pixel values: {image.getextrema()}")
# Out:
# Image dimension: (28, 28)
# Range of pixel values: (0, 255)

# %%
print(f"Label of the first image in the training set: {label}")
# Out:
# Label of the first image in the training set: 5

# %%
fig, axes = plt.subplots(1, 5, figsize=(12, 5))
for i in range(5):
    image, label = ds_train[i]
    axes[i].imshow(image)
    axes[i].set_title(f"Label: {label}")
    axes[i].axis('off')
plt.show()

# %%
from collections import Counter

count = Counter([label for _, label in ds_train])

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].bar(count.keys(), count.values())
ax[0].set_title('Distribution of labels in the training set')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('# of images')

ax[1].bar(count.keys(), count.values())
ax[1].set_title('Distribution of labels in the test set')
ax[1].set_xlabel('Label')
ax[1].set_ylabel('# of images')

plt.show()

# %% [markdown]
# ### Exercise 1.2: Dataset conversion and normalization
#
# + **Datatype Conversion**:
# The first thing we need to do is convert all data tensors to `torch.float32` -- this is fundamental as it is extremely inconvenient to work with `uint8` data. Using 32-bit floating point numbers is a compromise between precision and space efficiency.
# The `torch.Tensor` class has a very useful method `to()` for performing datatype and device (e.g. to GPU) conversions. Check out the [documentation here](https://pytorch.org/docs/stable/generated/torch.Tensor.to.html#torch-tensor-to).
#
# + **Normalization**:
# Next, we need to correct the inconvenient range of [0, 255] for the pixel values. You should *subtract* the mean intensity value and divide by the standard deviation in order to *standardize* our data. **Important**: Think *very carefully* about *which* split you should use to compute the pixel statistics for standardization.
#
# + **Reshaping**: Is the data in an appropriate format (i.e. shape) for the training the models we know? Think about whether (and how) to fix this if needed.
#
# **What to do**: In the cell below you should perform this sequence preprocessing operations on the `ds_train.data` and `ds_test.data` tensors.

# %%
# datatype conversion
ds_train.data = ds_train.data.to(torch.float32)
ds_test.data = ds_test.data.to(torch.float32)

# normalization
mean = ds_train.data.mean().item()
std = ds_train.data.std().item()
ds_train.data = (ds_train.data - mean) / std
ds_test.data = (ds_test.data - mean) / std

# reshaping
print(f"Shape of training data before reshaping: {ds_train.data.shape}")
print(f"Shape of test data before reshaping: {ds_test.data.shape}")

ds_train.data = ds_train.data.unsqueeze(1)  
ds_test.data = ds_test.data.unsqueeze(1)    

print(f"\nShape of training data after reshaping: {ds_train.data.shape}")
print(f"Shape of test data after reshaping: {ds_test.data.shape}")
print(f"Type of training data: {ds_train.data.dtype}")
print(f"Type of training data: {ds_test.data.dtype}")
# Out:
# Shape of training data before reshaping: torch.Size([60000, 28, 28])
# Shape of test data before reshaping: torch.Size([10000, 28, 28])
#
# Shape of training data after reshaping: torch.Size([60000, 1, 28, 28])
# Shape of test data after reshaping: torch.Size([10000, 1, 28, 28])
# Type of training data: torch.float32
# Type of training data: torch.float32

# %% [markdown]
# I dati erano inizialmente della forma (N, 28, 28) ma per un modello di deep learning abbiamo bisogno di dati nella forma (N, 1, 28, 28). Abbiamo quindi aggiunto una dimensione.

# %% [markdown]
# ### Exercise 1.3: Subsampling the MNIST dataset.
#
# MNIST is kind of big, and thus inconvenient to work with unless using the GPU. For this laboratory we will use a smaller subset of the dataset for training to keep memory and computation times low.
#
# Modify `ds.train` to use only a subset of, say, 10000 images sampled from the original data. Make sure to select the correct corresponding targets.

# %%
from torch.utils.data import Subset

indices = torch.randperm(len(ds_train))[:10000]

ds_train.data = ds_train.data[indices]
ds_train.targets = ds_train.targets[indices]

print(f"\nShape of training data (subset): {ds_train.data.shape}")
print(f"Shape of test data (subset): {ds_test.data.shape}")
# Out:
# Shape of training data (subset): torch.Size([10000, 1, 28, 28])
# Shape of test data (subset): torch.Size([10000, 1, 28, 28])

# %% [markdown]
# ## Establishing a stable baseline
#
# In this exercise you will establish a reliable baseline using a classical approach. This is an important step in our methodology in order to judge whether our Deep MLP is performing well or not.
#
# ### Exercise 2.1: Establish the stable baseline
#
# Train and test your stable baseline to estimate the best achievable accuracy using classical models.
#
# **Tip**: Don't do any extensive cross-validation of your baseline (for now). Just fit a simple model (e.g. a linear SVM) and record the accuracy.

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

# converto i tensori in array numpy per scikit-learn
X_train = ds_train.data.view(-1, 28*28).numpy()
y_train = ds_train.targets.numpy()
X_test = ds_test.data.view(-1, 28*28).numpy()
y_test = ds_test.targets.numpy()

svm_model = LinearSVC(max_iter=10000)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8695

# %% [markdown]
# ## Part 3: Training some deep models (finally)
#
# Now we will finally train some deep models (Multilayer Perceptrons, to be precise). Since the dataset is a bit too large to use batch gradient descent, we will first need to setup a `torch.utils.data.DataLoader` for our training data. A `DataLoader` breaks the dataset up into a sequence of *batches* that will be used for training. In order to use this, we will first have to use `torch.utils.data.TensorDataset` on `ds_train.data` and `ds_train.targets` to make a new torch `dataset` for use in the dataloader.
#
# ### Exercise 3.1: Creating the DataLoader
#
# Create a `DataLoader` for `ds_train` use a `batch_size` of about 16 or 32 to start. After you have your `DataLoader` experiment with is using `next(iter(dl_train))` to see what it returns. The pytorch `DataLoader` is a Python iterator.
#
# **EXTREMELY IMPORTANT**: Make sure you use `shuffle=True` in the constructor of your dataloader.

# %%
from torch.utils.data import DataLoader, TensorDataset

batch_size = 32

train_dataset = TensorDataset(ds_train.data, ds_train.targets)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = TensorDataset(ds_test.data, ds_test.targets)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


images, labels = next(iter(train_loader))
print(f"Batch shape of images: {images.shape}") 
print(f"Batch shape of labels: {labels.shape}") 
print(f"Image data type: {images.dtype}")  
print(f"Label data type: {labels.dtype}")
# Out:
# Batch shape of images: torch.Size([32, 1, 28, 28])
# Batch shape of labels: torch.Size([32])
# Image data type: torch.float32
# Label data type: torch.int64

# %% [markdown]
# ### Some support code (NOT an exercise).
#
# Here is some support code that you can use to train a model for a **single** epoch. The function returns the mean loss over all iterations. You will use it in the next exercise to train and monitor training.

# %%
# Train a model for a single epoch. You should pass it a model, a dataloader,
# and an optimizer. Returns the mean loss over the entire epoch.
def train_epoch(model, dl, optimizer):
    model.train()
    losses = []
    for (xs, ys) in dl:
        optimizer.zero_grad()
        output = model(xs)
        loss = torch.nn.functional.nll_loss(output, ys)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    model.eval()
    return np.mean(losses)

# %% [markdown]
# ### Exercise 3.2: Defining a 1-layer neural network
#
# Define a simple model that uses a **single** `torch.nn.Linear` layer followed by a `torch.nn.Softmax` to predict  the output probabilities for the ten classes.

# %%
import torch
import torch.nn as nn

model = torch.nn.Sequential(
    nn.Flatten(),
    nn.Linear(28*28, 10), 
    nn.LogSoftmax(dim=1)  
)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=10, bias=True)
#   (2): LogSoftmax(dim=1)
# )

# %% [markdown]
# ### Exercise 3.2: Training our model
#
# Instantiate a `torch.optim.SGD` optimizer using `model.parameters()` and the learning rate (**tip**: make the learning rate variable you can easily change). Then run `train_epoch` for a set number of epochs (e.g. 100, make this a variable too). Is your model learning? How can you tell?

# %%
import torch.optim as optim

def evaluate(model, dl):
    model.eval()
    correct = 0
    total = 0
    losses = []
    with torch.no_grad():
        for (xs, ys) in dl:
            output = model(xs)
            loss = torch.nn.functional.nll_loss(output, ys)
            losses.append(loss.item())
            _, predicted = torch.max(output, 1)
            total += ys.size(0)
            correct += (predicted == ys).sum().item()
    accuracy = correct / total
    avg_loss = np.mean(losses)
    return accuracy, avg_loss

learning_rate = 0.001
num_epochs = 100

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

train_losses = [] 
test_losses = []
test_accuracies = []
for epoch in range(num_epochs):
    avg_loss = train_epoch(model, train_loader, optimizer)
    train_losses.append(avg_loss)
    test_accuracy, test_loss = evaluate(model, test_loader)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}/{num_epochs}, Train average loss: {avg_loss:.4f}, Test average loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/100, Train average loss: 1.4108, Test average loss: 0.9373, Test accuracy: 0.7913
# Epoch 2/100, Train average loss: 0.8176, Test average loss: 0.6927, Test accuracy: 0.8418
# Epoch 3/100, Train average loss: 0.6573, Test average loss: 0.5919, Test accuracy: 0.8598
# Epoch 4/100, Train average loss: 0.5789, Test average loss: 0.5353, Test accuracy: 0.8699
# Epoch 5/100, Train average loss: 0.5314, Test average loss: 0.4980, Test accuracy: 0.8758
# Epoch 6/100, Train average loss: 0.4991, Test average loss: 0.4718, Test accuracy: 0.8803
# Epoch 7/100, Train average loss: 0.4740, Test average loss: 0.4514, Test accuracy: 0.8837
# Epoch 8/100, Train average loss: 0.4547, Test average loss: 0.4360, Test accuracy: 0.8857
# Epoch 9/100, Train average loss: 0.4394, Test average loss: 0.4235, Test accuracy: 0.8878
# Epoch 10/100, Train average loss: 0.4267, Test average loss: 0.4124, Test accuracy: 0.8905
# Epoch 11/100, Train average loss: 0.4154, Test average loss: 0.4034, Test accuracy: 0.8925
# Epoch 12/100, Train average loss: 0.4063, Test average loss: 0.3958, Test accuracy: 0.8932
# Epoch 13/100, Train average loss: 0.3983, Test average loss: 0.3892, Test accuracy: 0.8943
# Epoch 14/100, Train average loss: 0.3909, Test average loss: 0.3836, Test accuracy: 0.8968
# Epoch 15/100, Train average loss: 0.3843, Test average loss: 0.3787, Test accuracy: 0.8966
# Epoch 16/100, Train average loss: 0.3784, Test average loss: 0.3737, Test accuracy: 0.8968
# Epoch 17/100, Train average loss: 0.3732, Test average loss: 0.3698, Test accuracy: 0.8979
# Epoch 18/100, Train average loss: 0.3681, Test average loss: 0.3661, Test accuracy: 0.8985
# Epoch 19/100, Train average loss: 0.3640, Test average loss: 0.3627, Test accuracy: 0.8992
# Epoch 20/100, Train average loss: 0.3594, Test average loss: 0.3594, Test accuracy: 0.9007
# Epoch 21/100, Train average loss: 0.3560, Test average loss: 0.3566, Test accuracy: 0.9009
# Epoch 22/100, Train average loss: 0.3518, Test average loss: 0.3541, Test accuracy: 0.9015
# Epoch 23/100, Train average loss: 0.3488, Test average loss: 0.3517, Test accuracy: 0.9024
# Epoch 24/100, Train average loss: 0.3453, Test average loss: 0.3497, Test accuracy: 0.9027
# Epoch 25/100, Train average loss: 0.3428, Test average loss: 0.3473, Test accuracy: 0.9037
# Epoch 26/100, Train average loss: 0.3399, Test average loss: 0.3455, Test accuracy: 0.9039
# Epoch 27/100, Train average loss: 0.3375, Test average loss: 0.3434, Test accuracy: 0.9048
# Epoch 28/100, Train average loss: 0.3348, Test average loss: 0.3417, Test accuracy: 0.9051
# Epoch 29/100, Train average loss: 0.3321, Test average loss: 0.3399, Test accuracy: 0.9061
# Epoch 30/100, Train average loss: 0.3298, Test average loss: 0.3384, Test accuracy: 0.9065
# Epoch 31/100, Train average loss: 0.3281, Test average loss: 0.3375, Test accuracy: 0.9059
# Epoch 32/100, Train average loss: 0.3254, Test average loss: 0.3358, Test accuracy: 0.9066
# Epoch 33/100, Train average loss: 0.3240, Test average loss: 0.3343, Test accuracy: 0.9064
# Epoch 34/100, Train average loss: 0.3219, Test average loss: 0.3335, Test accuracy: 0.9071
# Epoch 35/100, Train average loss: 0.3204, Test average loss: 0.3327, Test accuracy: 0.9070
# Epoch 36/100, Train average loss: 0.3180, Test average loss: 0.3315, Test accuracy: 0.9068
# Epoch 37/100, Train average loss: 0.3162, Test average loss: 0.3299, Test accuracy: 0.9076
# Epoch 38/100, Train average loss: 0.3146, Test average loss: 0.3291, Test accuracy: 0.9077
# Epoch 39/100, Train average loss: 0.3127, Test average loss: 0.3282, Test accuracy: 0.9081
# Epoch 40/100, Train average loss: 0.3114, Test average loss: 0.3275, Test accuracy: 0.9078
# Epoch 41/100, Train average loss: 0.3097, Test average loss: 0.3262, Test accuracy: 0.9083
# Epoch 42/100, Train average loss: 0.3082, Test average loss: 0.3254, Test accuracy: 0.9092
# Epoch 43/100, Train average loss: 0.3070, Test average loss: 0.3244, Test accuracy: 0.9086
# Epoch 44/100, Train average loss: 0.3053, Test average loss: 0.3243, Test accuracy: 0.9083
# Epoch 45/100, Train average loss: 0.3045, Test average loss: 0.3233, Test accuracy: 0.9083
# Epoch 46/100, Train average loss: 0.3029, Test average loss: 0.3225, Test accuracy: 0.9089
# Epoch 47/100, Train average loss: 0.3015, Test average loss: 0.3216, Test accuracy: 0.9088
# Epoch 48/100, Train average loss: 0.3003, Test average loss: 0.3215, Test accuracy: 0.9091
# Epoch 49/100, Train average loss: 0.2991, Test average loss: 0.3203, Test accuracy: 0.9082
# Epoch 50/100, Train average loss: 0.2979, Test average loss: 0.3201, Test accuracy: 0.9089
# Epoch 51/100, Train average loss: 0.2970, Test average loss: 0.3193, Test accuracy: 0.9085
# Epoch 52/100, Train average loss: 0.2957, Test average loss: 0.3187, Test accuracy: 0.9093
# Epoch 53/100, Train average loss: 0.2945, Test average loss: 0.3183, Test accuracy: 0.9095
# Epoch 54/100, Train average loss: 0.2940, Test average loss: 0.3176, Test accuracy: 0.9099
# Epoch 55/100, Train average loss: 0.2928, Test average loss: 0.3172, Test accuracy: 0.9100
# Epoch 56/100, Train average loss: 0.2919, Test average loss: 0.3169, Test accuracy: 0.9095
# Epoch 57/100, Train average loss: 0.2908, Test average loss: 0.3167, Test accuracy: 0.9096
# Epoch 58/100, Train average loss: 0.2895, Test average loss: 0.3158, Test accuracy: 0.9099
# Epoch 59/100, Train average loss: 0.2885, Test average loss: 0.3159, Test accuracy: 0.9104
# Epoch 60/100, Train average loss: 0.2876, Test average loss: 0.3157, Test accuracy: 0.9103
# Epoch 61/100, Train average loss: 0.2869, Test average loss: 0.3152, Test accuracy: 0.9100
# Epoch 62/100, Train average loss: 0.2863, Test average loss: 0.3143, Test accuracy: 0.9098
# Epoch 63/100, Train average loss: 0.2856, Test average loss: 0.3140, Test accuracy: 0.9101
# Epoch 64/100, Train average loss: 0.2841, Test average loss: 0.3137, Test accuracy: 0.9106
# Epoch 65/100, Train average loss: 0.2833, Test average loss: 0.3131, Test accuracy: 0.9102
# Epoch 66/100, Train average loss: 0.2825, Test average loss: 0.3127, Test accuracy: 0.9098
# Epoch 67/100, Train average loss: 0.2817, Test average loss: 0.3127, Test accuracy: 0.9104
# Epoch 68/100, Train average loss: 0.2818, Test average loss: 0.3125, Test accuracy: 0.9106
# Epoch 69/100, Train average loss: 0.2813, Test average loss: 0.3121, Test accuracy: 0.9109
# Epoch 70/100, Train average loss: 0.2796, Test average loss: 0.3119, Test accuracy: 0.9101
# Epoch 71/100, Train average loss: 0.2788, Test average loss: 0.3112, Test accuracy: 0.9105
# Epoch 72/100, Train average loss: 0.2780, Test average loss: 0.3109, Test accuracy: 0.9108
# Epoch 73/100, Train average loss: 0.2776, Test average loss: 0.3111, Test accuracy: 0.9101
# Epoch 74/100, Train average loss: 0.2768, Test average loss: 0.3105, Test accuracy: 0.9106
# Epoch 75/100, Train average loss: 0.2760, Test average loss: 0.3101, Test accuracy: 0.9106
# Epoch 76/100, Train average loss: 0.2752, Test average loss: 0.3100, Test accuracy: 0.9107
# Epoch 77/100, Train average loss: 0.2747, Test average loss: 0.3099, Test accuracy: 0.9107
# Epoch 78/100, Train average loss: 0.2739, Test average loss: 0.3099, Test accuracy: 0.9102
# Epoch 79/100, Train average loss: 0.2732, Test average loss: 0.3095, Test accuracy: 0.9108
# Epoch 80/100, Train average loss: 0.2725, Test average loss: 0.3092, Test accuracy: 0.9107
# Epoch 81/100, Train average loss: 0.2722, Test average loss: 0.3090, Test accuracy: 0.9106
# Epoch 82/100, Train average loss: 0.2713, Test average loss: 0.3087, Test accuracy: 0.9108
# Epoch 83/100, Train average loss: 0.2706, Test average loss: 0.3084, Test accuracy: 0.9111
# Epoch 84/100, Train average loss: 0.2701, Test average loss: 0.3085, Test accuracy: 0.9112
# Epoch 85/100, Train average loss: 0.2696, Test average loss: 0.3081, Test accuracy: 0.9119
# Epoch 86/100, Train average loss: 0.2689, Test average loss: 0.3083, Test accuracy: 0.9111
# Epoch 87/100, Train average loss: 0.2682, Test average loss: 0.3082, Test accuracy: 0.9112
# Epoch 88/100, Train average loss: 0.2679, Test average loss: 0.3080, Test accuracy: 0.9113
# Epoch 89/100, Train average loss: 0.2671, Test average loss: 0.3079, Test accuracy: 0.9112
# Epoch 90/100, Train average loss: 0.2671, Test average loss: 0.3075, Test accuracy: 0.9116
# Epoch 91/100, Train average loss: 0.2665, Test average loss: 0.3076, Test accuracy: 0.9116
# Epoch 92/100, Train average loss: 0.2654, Test average loss: 0.3076, Test accuracy: 0.9112
# Epoch 93/100, Train average loss: 0.2657, Test average loss: 0.3069, Test accuracy: 0.9114
# Epoch 94/100, Train average loss: 0.2654, Test average loss: 0.3067, Test accuracy: 0.9113
# Epoch 95/100, Train average loss: 0.2640, Test average loss: 0.3069, Test accuracy: 0.9110
# Epoch 96/100, Train average loss: 0.2633, Test average loss: 0.3069, Test accuracy: 0.9118
# Epoch 97/100, Train average loss: 0.2627, Test average loss: 0.3066, Test accuracy: 0.9115
# Epoch 98/100, Train average loss: 0.2625, Test average loss: 0.3063, Test accuracy: 0.9117
# Epoch 99/100, Train average loss: 0.2622, Test average loss: 0.3064, Test accuracy: 0.9115
# Epoch 100/100, Train average loss: 0.2613, Test average loss: 0.3060, Test accuracy: 0.9113

# %% [markdown]
# Possiamo vedere che la loss tende a diminuire ad ogni epoca, questo implica che il modello sta imparando e riesce a predirre sempre meglio le etichette

# %% [markdown]
# ### Exercise 3.3: Evaluating our model
#
# Write some code to plot the loss curve for your training run and evaluate the performance of your model on the test data. Play with the hyperparameters (e.g. learning rate) to try to get the best performance on the test set. Can you beat the stable baseline?

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Test Loss over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Test Accuracy over Epochs')
plt.legend()

plt.show()

# %% [markdown]
# ## Going Deeper
#
# Now we will go (at least one layer) deeper to see if we can significantly improve on the baseline.
#
# ### Exercise 3.4: A 2-layer MLP
# Define a new model with one hidden layer. Use the code you wrote above to train and evaluate this new model. Can you beat the baseline? You might need to train in two stages using different learning rates.
#
# **Things to think about**:
#
# + It might be hard to beat (or even equal) the baseline with deeper networks. Why?
# + Is there something else we should be monitoring while training, especially for deep networks?

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.flatten = nn.Flatten()
        self.hidden = nn.Linear(28*28, 128)  # Livello nascosto con 128 neuroni
        self.relu = nn.ReLU()
        self.output = nn.Linear(128, 10)  # Strato di output con 10 neuroni
        self.log_softmax = nn.LogSoftmax(dim=1)
    
    def forward(self, x):
        x = self.flatten(x)
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)
        x = self.log_softmax(x)
        return x

model = SimpleNN()

# %%
model = SimpleNN()

learning_rate_phase1 = 0.01
learning_rate_phase2 = 0.001
optimizer = optim.SGD(model.parameters(), lr=learning_rate_phase1)

num_epochs_phase1 = 50
num_epochs_phase2 = 50

train_losses = []
test_losses = []
test_accuracies = []

print('Phase 1\n')
for epoch in range(num_epochs_phase1):
    avg_loss = train_epoch(model, train_loader, optimizer)
    train_losses.append(avg_loss)
    
    test_accuracy, test_loss = evaluate(model, test_loader)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    
    print(f"Epoch {epoch + 1}/{num_epochs_phase1}, Train average loss: {avg_loss:.4f}, Test average loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")


print('\nPhase 2\n')
optimizer = optim.SGD(model.parameters(), lr=learning_rate_phase2)
for epoch in range(num_epochs_phase2):
    avg_loss = train_epoch(model, train_loader, optimizer)
    train_losses.append(avg_loss)
    
    test_accuracy, test_loss = evaluate(model, test_loader)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    
    print(f"Epoch {epoch + 1}/{num_epochs_phase2}, Train average loss: {avg_loss:.4f}, Test average loss: {test_loss:.4f}, Test accuracy: {test_accuracy:.4f}")
# Out:
# Phase 1
#
# Epoch 1/50, Train average loss: 0.9718, Test average loss: 0.4792, Test accuracy: 0.8778
# Epoch 2/50, Train average loss: 0.4236, Test average loss: 0.3693, Test accuracy: 0.8951
# Epoch 3/50, Train average loss: 0.3480, Test average loss: 0.3280, Test accuracy: 0.9067
# Epoch 4/50, Train average loss: 0.3088, Test average loss: 0.3005, Test accuracy: 0.9127
# Epoch 5/50, Train average loss: 0.2817, Test average loss: 0.2820, Test accuracy: 0.9191
# Epoch 6/50, Train average loss: 0.2588, Test average loss: 0.2719, Test accuracy: 0.9213
# Epoch 7/50, Train average loss: 0.2408, Test average loss: 0.2592, Test accuracy: 0.9243
# Epoch 8/50, Train average loss: 0.2237, Test average loss: 0.2516, Test accuracy: 0.9263
# Epoch 9/50, Train average loss: 0.2088, Test average loss: 0.2379, Test accuracy: 0.9268
# Epoch 10/50, Train average loss: 0.1957, Test average loss: 0.2311, Test accuracy: 0.9320
# Epoch 11/50, Train average loss: 0.1837, Test average loss: 0.2209, Test accuracy: 0.9332
# Epoch 12/50, Train average loss: 0.1728, Test average loss: 0.2153, Test accuracy: 0.9368
# Epoch 13/50, Train average loss: 0.1627, Test average loss: 0.2110, Test accuracy: 0.9373
# Epoch 14/50, Train average loss: 0.1537, Test average loss: 0.2050, Test accuracy: 0.9399
# Epoch 15/50, Train average loss: 0.1454, Test average loss: 0.2003, Test accuracy: 0.9403
# Epoch 16/50, Train average loss: 0.1377, Test average loss: 0.1956, Test accuracy: 0.9413
# Epoch 17/50, Train average loss: 0.1299, Test average loss: 0.1939, Test accuracy: 0.9413
# Epoch 18/50, Train average loss: 0.1230, Test average loss: 0.1914, Test accuracy: 0.9417
# Epoch 19/50, Train average loss: 0.1168, Test average loss: 0.1859, Test accuracy: 0.9434
# Epoch 20/50, Train average loss: 0.1112, Test average loss: 0.1843, Test accuracy: 0.9445
# Epoch 21/50, Train average loss: 0.1050, Test average loss: 0.1800, Test accuracy: 0.9449
# Epoch 22/50, Train average loss: 0.1002, Test average loss: 0.1783, Test accuracy: 0.9459
# Epoch 23/50, Train average loss: 0.0948, Test average loss: 0.1738, Test accuracy: 0.9471
# Epoch 24/50, Train average loss: 0.0906, Test average loss: 0.1753, Test accuracy: 0.9460
# Epoch 25/50, Train average loss: 0.0861, Test average loss: 0.1700, Test accuracy: 0.9481
# Epoch 26/50, Train average loss: 0.0817, Test average loss: 0.1722, Test accuracy: 0.9481
# Epoch 27/50, Train average loss: 0.0780, Test average loss: 0.1671, Test accuracy: 0.9492
# Epoch 28/50, Train average loss: 0.0740, Test average loss: 0.1657, Test accuracy: 0.9507
# Epoch 29/50, Train average loss: 0.0707, Test average loss: 0.1653, Test accuracy: 0.9501
# Epoch 30/50, Train average loss: 0.0673, Test average loss: 0.1636, Test accuracy: 0.9505
# Epoch 31/50, Train average loss: 0.0644, Test average loss: 0.1646, Test accuracy: 0.9497
# Epoch 32/50, Train average loss: 0.0612, Test average loss: 0.1614, Test accuracy: 0.9511
# Epoch 33/50, Train average loss: 0.0583, Test average loss: 0.1591, Test accuracy: 0.9509
# Epoch 34/50, Train average loss: 0.0559, Test average loss: 0.1592, Test accuracy: 0.9516
# Epoch 35/50, Train average loss: 0.0533, Test average loss: 0.1575, Test accuracy: 0.9523
# Epoch 36/50, Train average loss: 0.0512, Test average loss: 0.1577, Test accuracy: 0.9524
# Epoch 37/50, Train average loss: 0.0487, Test average loss: 0.1577, Test accuracy: 0.9524
# Epoch 38/50, Train average loss: 0.0467, Test average loss: 0.1591, Test accuracy: 0.9526
# Epoch 39/50, Train average loss: 0.0448, Test average loss: 0.1564, Test accuracy: 0.9529
# Epoch 40/50, Train average loss: 0.0430, Test average loss: 0.1573, Test accuracy: 0.9526
# Epoch 41/50, Train average loss: 0.0409, Test average loss: 0.1593, Test accuracy: 0.9528
# Epoch 42/50, Train average loss: 0.0394, Test average loss: 0.1551, Test accuracy: 0.9532
# Epoch 43/50, Train average loss: 0.0379, Test average loss: 0.1534, Test accuracy: 0.9543
# Epoch 44/50, Train average loss: 0.0363, Test average loss: 0.1559, Test accuracy: 0.9537
# Epoch 45/50, Train average loss: 0.0349, Test average loss: 0.1542, Test accuracy: 0.9538
# Epoch 46/50, Train average loss: 0.0334, Test average loss: 0.1539, Test accuracy: 0.9550
# Epoch 47/50, Train average loss: 0.0323, Test average loss: 0.1540, Test accuracy: 0.9549
# Epoch 48/50, Train average loss: 0.0310, Test average loss: 0.1527, Test accuracy: 0.9541
# Epoch 49/50, Train average loss: 0.0300, Test average loss: 0.1528, Test accuracy: 0.9550
# Epoch 50/50, Train average loss: 0.0288, Test average loss: 0.1527, Test accuracy: 0.9546
#
# Phase 2
#
# Epoch 1/50, Train average loss: 0.0265, Test average loss: 0.1526, Test accuracy: 0.9551
# Epoch 2/50, Train average loss: 0.0263, Test average loss: 0.1527, Test accuracy: 0.9550
# Epoch 3/50, Train average loss: 0.0261, Test average loss: 0.1526, Test accuracy: 0.9556
# Epoch 4/50, Train average loss: 0.0261, Test average loss: 0.1526, Test accuracy: 0.9555
# Epoch 5/50, Train average loss: 0.0259, Test average loss: 0.1526, Test accuracy: 0.9555
# Epoch 6/50, Train average loss: 0.0259, Test average loss: 0.1527, Test accuracy: 0.9557
# Epoch 7/50, Train average loss: 0.0258, Test average loss: 0.1525, Test accuracy: 0.9557
# Epoch 8/50, Train average loss: 0.0256, Test average loss: 0.1524, Test accuracy: 0.9554
# Epoch 9/50, Train average loss: 0.0255, Test average loss: 0.1525, Test accuracy: 0.9553
# Epoch 10/50, Train average loss: 0.0255, Test average loss: 0.1525, Test accuracy: 0.9555
# Epoch 11/50, Train average loss: 0.0254, Test average loss: 0.1524, Test accuracy: 0.9554
# Epoch 12/50, Train average loss: 0.0253, Test average loss: 0.1525, Test accuracy: 0.9553
# Epoch 13/50, Train average loss: 0.0253, Test average loss: 0.1524, Test accuracy: 0.9553
# Epoch 14/50, Train average loss: 0.0252, Test average loss: 0.1524, Test accuracy: 0.9557
# Epoch 15/50, Train average loss: 0.0250, Test average loss: 0.1525, Test accuracy: 0.9557
# Epoch 16/50, Train average loss: 0.0249, Test average loss: 0.1525, Test accuracy: 0.9557
# Epoch 17/50, Train average loss: 0.0249, Test average loss: 0.1526, Test accuracy: 0.9558
# Epoch 18/50, Train average loss: 0.0248, Test average loss: 0.1525, Test accuracy: 0.9556
# Epoch 19/50, Train average loss: 0.0247, Test average loss: 0.1525, Test accuracy: 0.9557
# Epoch 20/50, Train average loss: 0.0247, Test average loss: 0.1524, Test accuracy: 0.9554
# Epoch 21/50, Train average loss: 0.0245, Test average loss: 0.1523, Test accuracy: 0.9553
# Epoch 22/50, Train average loss: 0.0245, Test average loss: 0.1522, Test accuracy: 0.9559
# Epoch 23/50, Train average loss: 0.0244, Test average loss: 0.1524, Test accuracy: 0.9557
# Epoch 24/50, Train average loss: 0.0244, Test average loss: 0.1524, Test accuracy: 0.9561
# Epoch 25/50, Train average loss: 0.0242, Test average loss: 0.1523, Test accuracy: 0.9559
# Epoch 26/50, Train average loss: 0.0241, Test average loss: 0.1525, Test accuracy: 0.9557
# Epoch 27/50, Train average loss: 0.0241, Test average loss: 0.1524, Test accuracy: 0.9558
# Epoch 28/50, Train average loss: 0.0240, Test average loss: 0.1524, Test accuracy: 0.9560
# Epoch 29/50, Train average loss: 0.0239, Test average loss: 0.1525, Test accuracy: 0.9556
# Epoch 30/50, Train average loss: 0.0238, Test average loss: 0.1524, Test accuracy: 0.9559
# Epoch 31/50, Train average loss: 0.0238, Test average loss: 0.1523, Test accuracy: 0.9558
# Epoch 32/50, Train average loss: 0.0237, Test average loss: 0.1523, Test accuracy: 0.9556
# Epoch 33/50, Train average loss: 0.0236, Test average loss: 0.1522, Test accuracy: 0.9557
# Epoch 34/50, Train average loss: 0.0236, Test average loss: 0.1523, Test accuracy: 0.9557
# Epoch 35/50, Train average loss: 0.0234, Test average loss: 0.1524, Test accuracy: 0.9557
# Epoch 36/50, Train average loss: 0.0234, Test average loss: 0.1523, Test accuracy: 0.9563
# Epoch 37/50, Train average loss: 0.0233, Test average loss: 0.1522, Test accuracy: 0.9560
# Epoch 38/50, Train average loss: 0.0232, Test average loss: 0.1523, Test accuracy: 0.9559
# Epoch 39/50, Train average loss: 0.0231, Test average loss: 0.1523, Test accuracy: 0.9559
# Epoch 40/50, Train average loss: 0.0231, Test average loss: 0.1524, Test accuracy: 0.9561
# Epoch 41/50, Train average loss: 0.0230, Test average loss: 0.1524, Test accuracy: 0.9559
# Epoch 42/50, Train average loss: 0.0229, Test average loss: 0.1524, Test accuracy: 0.9561
# Epoch 43/50, Train average loss: 0.0228, Test average loss: 0.1524, Test accuracy: 0.9560
# Epoch 44/50, Train average loss: 0.0228, Test average loss: 0.1524, Test accuracy: 0.9560
# Epoch 45/50, Train average loss: 0.0227, Test average loss: 0.1523, Test accuracy: 0.9562
# Epoch 46/50, Train average loss: 0.0226, Test average loss: 0.1523, Test accuracy: 0.9560
# Epoch 47/50, Train average loss: 0.0226, Test average loss: 0.1523, Test accuracy: 0.9560
# Epoch 48/50, Train average loss: 0.0225, Test average loss: 0.1523, Test accuracy: 0.9559
# Epoch 49/50, Train average loss: 0.0224, Test average loss: 0.1524, Test accuracy: 0.9558
# Epoch 50/50, Train average loss: 0.0227, Test average loss: 0.1523, Test accuracy: 0.9559

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Test Loss over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Test Accuracy over Epochs')
plt.legend()

plt.show()

# %% [markdown]
# I modelli con reti più profonde possono essere difficili da addestrare a causa dei problemi legati ad esempio al vanishing gradient o comunque a causa della maggiore complessità di ottimizzazione rispetto a modelli più semplici. Dovremmo quindi monitorare i gradienti per evitare problemi di vanishing gradient o di esplosione del gradiente, monitorare le attivazioni nei vari strati per identificare problemi di saturazione e osservare l'accuratezza su un set di validazione per rilevare overfitting e implementare tecniche di stopping per interrompere l'addestramento quando le prestazioni non migliorano più.
